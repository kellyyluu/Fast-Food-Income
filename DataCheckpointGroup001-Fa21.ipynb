# %% [markdown]
# # COGS 108 - Data Checkpoint

# %% [markdown]
# # Names
#
# - Nicholas Fisher
# - Kelly Luu
# - Isiah Nicasio
# - Destynee Tau

# %% [markdown]
# <a id='research_question'></a>
# # Research Question

# %% [markdown]
# How does housing median income affect the concentration of fast food restaurants within California?

# %% [markdown]
# # Dataset(s)

# %% [markdown]
# - Dataset Name: Fast food restaurants across US We are given the name of the restaurant, the location and type
#
# - Link to the dataset: https://www.kaggle.com/khushishahh/fast-food-restaurants-across-us
#
# - Number of observations: 10000 observations and 11 attributes
#
#
#
# - Dataset Name: California Housing Prices Data (5 new features!)
#
# - Link to the dataset: https://www.kaggle.com/fedesoriano/california-housing-prices-data-extra-features
#
# - Number of observations: 20640 observations and 14 attributes
#
#
# 1-2 sentences describing each dataset.
#
# - A list of fast-food restaurants that includes their information about location, more specifically their address, city, country,  latitude, longitude and province.
#
# - Our other dataset is the price for housing in California which gives the price, location, the number of rooms in the house.
#
#
# If you plan to use multiple datasets, add 1-2 sentences about how you plan to combine these datasets.
#
# - With both of these CSV files we will compare and contrast the concentration of fast food places within higher and lower economic places. We will combine these two datasets through latitude and longitude.

# %% [markdown]
# # Setup

# %%
## YOUR CODE HERE
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Describe your data cleaning steps here.
#
# For the Food Data Set:
# - We first imported the data files and looked at them.
# - We looked at the shape of each data.
# - We checked to see if there are any NAN values.
# - We dropped the 'categories' column because we decided it would be of no use in our project
# - We dropped the 'country' column because all the data was from  the US country so it was unneeded
# - We filtered the column for 'province' to be from only CA
# - we dropped the 'unnamed: 0' column because we decided that it had no use in our project
# - We then decided to lowercase all the strings in each columns so it would be easier to code in the future. (city, address, name, province, website, and the names of the columns)
# - Then we reset the index
# - We stripped each column to remove the white spaces
# - We then changed the postal code into all integer variables
# - Lastly, we viewed our data set to make sure we cleaned it
#
# For the House Data Set:
# - We first imported the data files and looked at them.
# - We looked at the shape of each data.
# - We checked to see if there are any NAN values.
# - Then we decided to lowercase all the strings of each column title

# %%
foodData = pd.read_csv('https://raw.githubusercontent.com/COGS108/Group001-Fa21/master/Fast_Food_Restaurants_US.csv?token=AUGC3VIT3IWCA5ZDVON3SW3BSRZ7W')
foodData
# Out:
#       Unnamed: 0               address  \
# 0              0      800 N Canal Blvd
# 1              1      800 N Canal Blvd
# 2              2   206 Wears Valley Rd
# 3              3          3652 Parkway
# 4              4  2118 Mt Zion Parkway
# ...          ...                   ...
# 9995        9995     3460 Robinhood Rd
# 9996        9996  3069 Kernersville Rd
# 9997        9997         838 S Main St
# 9998        9998   1702 Glendale Dr SW
# 9999        9999       1405 W Broad St
#
#                                         categories           city country  \
# 0     American Restaurant and Fast Food Restaurant      Thibodaux      US
# 1                            Fast Food Restaurants      Thibodaux      US
# 2                             Fast Food Restaurant   Pigeon Forge      US
# 3                                        Fast Food   Pigeon Forge      US
# 4                             Fast Food Restaurant         Morrow      US
# ...

# %%
foodData.shape
# Out:
# (10000, 11)

# %%
foodData.isnull().values.any()
# Out:
# False

# %%
foodData.dtypes
# Out:
# Unnamed: 0      int64
# address        object
# categories     object
# city           object
# country        object
# latitude      float64
# longitude     float64
# name           object
# postalCode     object
# province       object
# websites       object
# dtype: object

# %%
foodData['categories'].unique()
# Out:
# array(['American Restaurant and Fast Food Restaurant',
#        'Fast Food Restaurants', 'Fast Food Restaurant', 'Fast Food',
#        'Fast Food Restaurant and Ice Cream Shop',
#        'Ice Cream Shop and Fast Food Restaurant',
#        'Fast Food Restaurant and Mexican Restaurant',
#        'Fast Food Restaurant and Burger Joint', 'Fast food restaurants',
#        'Fast Food Restaurant, Mexican Restaurant, and Taco Place',
#        'American Restaurant, Sandwich Place, and Fast Food Restaurant',
#        'Fast Food Restaurant, American Restaurant, and Sandwich Place',
#        'Burger Joint and Fast Food Restaurant Gulf Breeze',
#        'Fast Food Restaurant, Sandwich Place, and American Restaurant',
#        'Restaurant, Fast Food Restaurant, and Sandwich Place',
#        'Fast Food Restaurant and Playground',
#        'Sandwich Place, Pizza Place, and Fast Food Restaurant',
#        'American Restaurant, Fast Food Restaurant, and Sandwich Place',
# ...

# %%
foodData['country'].unique()
# Out:
# array(['US'], dtype=object)

# %%
foodData['province'].unique()
# Out:
# array(['LA', 'TN', 'GA', 'MI', 'CA', 'NY', 'TX', 'OH', 'SC', 'MS', 'IN',
#        'MA', 'FL', 'MO', 'PA', 'IL', 'CT', 'KY', 'KS', 'IA', 'HI', 'ID',
#        'NC', 'DE', 'AZ', 'WI', 'CO', 'AR', 'SD', 'WV', 'WY', 'VA', 'OR',
#        'MD', 'WA', 'UT', 'NV', 'OK', 'ME', 'ND', 'NH', 'VT', 'NJ', 'NE',
#        'MN', 'MT', 'AL', 'NM', 'AK', 'RI'], dtype=object)

# %%
foodData = foodData.drop(columns = 'categories')
foodData = foodData.drop(columns = 'country')
foodData = foodData[foodData['province'] == 'CA']
foodData = foodData.drop(columns = 'Unnamed: 0')
foodData['city'] = foodData['city'].str.lower()
foodData['address'] = foodData['address'].str.lower()
foodData['name'] = foodData['name'].str.lower()
foodData['province'] = foodData['province'].str.lower()
foodData['websites'] = foodData['websites'].str.lower()
foodData.columns = foodData.columns.str.lower()
foodData = foodData.reset_index()
foodData = foodData.drop(columns = 'index')
foodData['address'] = foodData['address'].str.strip()
foodData['city'] = foodData['city'].str.strip()
foodData['name'] = foodData['name'].str.lower()
foodData['postalcode'] = foodData['postalcode'].str.lower()
foodData['province'] = foodData['province'].str.lower()
foodData['websites'] = foodData['websites'].str.lower()

# %%
foodData
# Out:
#                          address          city   latitude   longitude  \
# 0            4111 oceanside blvd     oceanside  33.205722 -117.288645
# 1           1190 w foothill blvd         azusa  34.133291 -117.924566
# 2                 6316 w 89th st   los angeles  33.955923 -118.396443
# 3                2992 jamacha rd      el cajon  32.739923 -116.942156
# 4              706 fletcher pkwy      el cajon  32.808270 -116.971370
# ...                          ...           ...        ...         ...
# 1196         11916 aviation blvd     inglewood  33.924828 -118.378075
# 1197            814 n ventura rd  port hueneme  34.155100 -119.195200
# 1198  401 w channel islands blvd  port hueneme  34.176370 -119.208850
# 1199  351 e channel islands blvd  port hueneme  34.176120 -119.195570
# 1200            1741 pacific ave        oxnard  34.180630 -119.164980
#
#                         name postalcode province  \
# 0     chipotle mexican grill      92056       ca
# ...

# %%
houseData = pd.read_csv('https://raw.githubusercontent.com/COGS108/Group001-Fa21/master/California_Houses.csv?token=AUGC3VOT7ONVESA67PZU2D3BSR2DA')
houseData
# Out:
#        Median_House_Value  Median_Income  Median_Age  Tot_Rooms  Tot_Bedrooms  \
# 0                452600.0         8.3252          41        880           129
# 1                358500.0         8.3014          21       7099          1106
# 2                352100.0         7.2574          52       1467           190
# 3                341300.0         5.6431          52       1274           235
# 4                342200.0         3.8462          52       1627           280
# ...                   ...            ...         ...        ...           ...
# 20635             78100.0         1.5603          25       1665           374
# 20636             77100.0         2.5568          18        697           150
# 20637             92300.0         1.7000          17       2254           485
# 20638             84700.0         1.8672          18       1860           409
# 20639             89400.0         2.3886          16       2785           616
#
# ...

# %%
houseData.shape
# Out:
# (20640, 14)

# %%
houseData.isnull().values.any()
# Out:
# False

# %%
houseData.columns = houseData.columns.str.lower()

# %%
houseData['median_income'] = 10000 * houseData['median_income']

# %%
foodData.drop_duplicates()
# Out:
#                          address          city   latitude   longitude  \
# 0            4111 oceanside blvd     oceanside  33.205722 -117.288645
# 1           1190 w foothill blvd         azusa  34.133291 -117.924566
# 2                 6316 w 89th st   los angeles  33.955923 -118.396443
# 3                2992 jamacha rd      el cajon  32.739923 -116.942156
# 4              706 fletcher pkwy      el cajon  32.808270 -116.971370
# ...                          ...           ...        ...         ...
# 1196         11916 aviation blvd     inglewood  33.924828 -118.378075
# 1197            814 n ventura rd  port hueneme  34.155100 -119.195200
# 1198  401 w channel islands blvd  port hueneme  34.176370 -119.208850
# 1199  351 e channel islands blvd  port hueneme  34.176120 -119.195570
# 1200            1741 pacific ave        oxnard  34.180630 -119.164980
#
#                         name postalcode province  \
# 0     chipotle mexican grill      92056       ca
# ...
